# %% [markdown]
# <a href="https://colab.research.google.com/github/kartikhatwaliya/Davistraining-/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#question-1
price = float(input("Enter price: "))
discount = float(input("Enter discount percentage: "))

final_price = price - (price * discount / 100)

print("Final price after discount:", final_price)
# Out:
# Enter price:  234
# Enter discount percentage: 2
# Final price after discount: 229.32
